# %%
# importing json file with necesseary library 
import json
import numpy as np 
import pandas as pd

#C:\Users\mo\Desktop\Twitter-Data-Analysis-Template

# %%
#loading twitter data
df= pd.read_json(r'C:\Users\mo\Desktop\Twitter-Data-Analysis-Template\data\global_twitter_data.json',lines=True)

# %%
df.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1 2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2 2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3 2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4 2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                            full_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# ...

# %% [markdown]
# # Data preprocessing

# %%
#Removing empty clumns 
df.dropna(axis=1,inplace=True)

# %%
df
# Out:
#                      created_at                   id               id_str  \
# 0     2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1     2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2     2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3     2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4     2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
# ...                         ...                  ...                  ...
# 21995 2022-08-06 18:03:29+00:00  1555977877383938048  1555977877383938048
# 21996 2022-08-06 18:03:27+00:00  1555977869746118661  1555977869746118656
# 21997 2022-08-06 18:03:27+00:00  1555977869293223937  1555977869293223936
# 21998 2022-08-06 18:03:26+00:00  1555977867174895616  1555977867174895616
# 21999 2022-08-06 18:03:25+00:00  1555977863475724289  1555977863475724288
#
#                                                full_text  truncated  \
# ...

# %%
#checking null value
df.isnull().count
# Out:
# <bound method DataFrame.count of        created_at     id  id_str  full_text  truncated  display_text_range  \
# 0           False  False   False      False      False               False
# 1           False  False   False      False      False               False
# 2           False  False   False      False      False               False
# 3           False  False   False      False      False               False
# 4           False  False   False      False      False               False
# ...           ...    ...     ...        ...        ...                 ...
# 21995       False  False   False      False      False               False
# 21996       False  False   False      False      False               False
# 21997       False  False   False      False      False               False
# 21998       False  False   False      False      False               False
# 21999       False  False   False      False      False               False
#
# ...

# %%
df.fillna(df.mean().round(1), inplace=True)
df.fillna(df.median().round(1), inplace=True)
# Out:
# <ipython-input-14-ab980a49e1c3>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean().round(1), inplace=True)
# <ipython-input-14-ab980a49e1c3>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.median().round(1), inplace=True)

# %%
print(df)
# Out:
#                      created_at                   id               id_str  \
# 0     2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1     2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2     2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3     2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4     2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
# ...                         ...                  ...                  ...
# 21995 2022-08-06 18:03:29+00:00  1555977877383938048  1555977877383938048
# 21996 2022-08-06 18:03:27+00:00  1555977869746118661  1555977869746118656
# 21997 2022-08-06 18:03:27+00:00  1555977869293223937  1555977869293223936
# 21998 2022-08-06 18:03:26+00:00  1555977867174895616  1555977867174895616
# 21999 2022-08-06 18:03:25+00:00  1555977863475724289  1555977863475724288
#
#                                                full_text  truncated  \
# ...

# %%
df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'metadata', 'source', 'user',
#        'is_quote_status', 'retweet_count', 'favorite_count', 'favorited',
#        'retweeted', 'lang'],
#       dtype='object')

# %%
df.select_dtypes(include=np.number)
# Out:
#                         id               id_str  retweet_count  favorite_count
# 0      1556407673284861952  1556407673284861952              2               0
# 1      1556407654373027840  1556407654373027840            201               0
# 2      1556407616208773122  1556407616208773120              0               0
# 3      1556407614602461185  1556407614602461184              0               0
# 4      1556407604238245889  1556407604238245888            381               0
# ...                    ...                  ...            ...             ...
# 21995  1555977877383938048  1555977877383938048            183               0
# 21996  1555977869746118661  1555977869746118656            183               0
# 21997  1555977869293223937  1555977869293223936              0               0
# 21998  1555977867174895616  1555977867174895616             67               0
# 21999  1555977863475724289  1555977863475724288             67               0
#
# ...

# %%
df.to_csv(r'C:\Users\mo\Desktop\Twitter-Data-Analysis-Template\global_twitter_data.json', index=False)
