# %%
# importing json file with necesseary library 
import json
import numpy as np 
import pandas as pd

#C:\Users\mo\Desktop\Twitter-Data-Analysis-Template

# %%
#loading twitter data
df= pd.read_json(r'C:\Users\mo\Desktop\Twitter-Data-Analysis-Template\covid19.json',lines=True)

# %%
df.head(5)
# Out:
#                  created_at                   id               id_str  \
# 0 2021-06-18 17:55:49+00:00  1405947374003015684  1405947374003015680
# 1 2021-06-18 17:55:59+00:00  1405947412364075010  1405947412364075008
# 2 2021-06-18 17:56:07+00:00  1405947447797587969  1405947447797587968
# 3 2021-06-18 17:56:10+00:00  1405947462028873729  1405947462028873728
# 4 2021-06-18 17:56:20+00:00  1405947503225229317  1405947503225229312
#
#                                                 text  \
# 0  RT @TelGlobalHealth: 🚨Africa is "in the midst ...
# 1  RT @globalhlthtwit: Dr Moeti is head of WHO in...
# 2  RT @NHSRDForum: Thank you @research2note for c...
# 3  RT @HighWireTalk: Former Pfizer VP and Virolog...
# 4  RT @PeterHotez: I think it’s important that we...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="https://mobile.twitter.com" rel="nofo...      False
# ...

# %% [markdown]
# # Data preprocessing

# %%
#checking null value
df.isnull()
# Out:
#        created_at     id  id_str  full_text  truncated  display_text_range  \
# 0           False  False   False      False      False               False
# 1           False  False   False      False      False               False
# 2           False  False   False      False      False               False
# 3           False  False   False      False      False               False
# 4           False  False   False      False      False               False
# ...           ...    ...     ...        ...        ...                 ...
# 21995       False  False   False      False      False               False
# 21996       False  False   False      False      False               False
# 21997       False  False   False      False      False               False
# 21998       False  False   False      False      False               False
# 21999       False  False   False      False      False               False
#
# ...

# %%
#Removing empty clumns 
df.dropna(axis=1,inplace=True)

# %%
df
# Out:
#                      created_at                   id               id_str  \
# 0     2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1     2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2     2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3     2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4     2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
# ...                         ...                  ...                  ...
# 21995 2022-08-06 18:03:29+00:00  1555977877383938048  1555977877383938048
# 21996 2022-08-06 18:03:27+00:00  1555977869746118661  1555977869746118656
# 21997 2022-08-06 18:03:27+00:00  1555977869293223937  1555977869293223936
# 21998 2022-08-06 18:03:26+00:00  1555977867174895616  1555977867174895616
# 21999 2022-08-06 18:03:25+00:00  1555977863475724289  1555977863475724288
#
#                                                full_text  truncated  \
# ...

# %%
df
# Out:
#                      created_at                   id               id_str  \
# 0     2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1     2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2     2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3     2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4     2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
# ...                         ...                  ...                  ...
# 21995 2022-08-06 18:03:29+00:00  1555977877383938048  1555977877383938048
# 21996 2022-08-06 18:03:27+00:00  1555977869746118661  1555977869746118656
# 21997 2022-08-06 18:03:27+00:00  1555977869293223937  1555977869293223936
# 21998 2022-08-06 18:03:26+00:00  1555977867174895616  1555977867174895616
# 21999 2022-08-06 18:03:25+00:00  1555977863475724289  1555977863475724288
#
#                                                full_text  truncated  \
# ...

# %%
#checking null value
df.isnull().count
# Out:
# <bound method DataFrame.count of        created_at     id  id_str  full_text  truncated  display_text_range  \
# 0           False  False   False      False      False               False
# 1           False  False   False      False      False               False
# 2           False  False   False      False      False               False
# 3           False  False   False      False      False               False
# 4           False  False   False      False      False               False
# ...           ...    ...     ...        ...        ...                 ...
# 21995       False  False   False      False      False               False
# 21996       False  False   False      False      False               False
# 21997       False  False   False      False      False               False
# 21998       False  False   False      False      False               False
# 21999       False  False   False      False      False               False
#
# ...

# %%
df.fillna(df.mean().round(1), inplace=True)
df.fillna(df.median().round(1), inplace=True)
# Out:
# <ipython-input-10-ab980a49e1c3>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean().round(1), inplace=True)
# <ipython-input-10-ab980a49e1c3>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.median().round(1), inplace=True)

# %%
print(df)
# Out:
#                      created_at                   id               id_str  \
# 0     2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1     2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2     2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3     2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4     2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
# ...                         ...                  ...                  ...
# 21995 2022-08-06 18:03:29+00:00  1555977877383938048  1555977877383938048
# 21996 2022-08-06 18:03:27+00:00  1555977869746118661  1555977869746118656
# 21997 2022-08-06 18:03:27+00:00  1555977869293223937  1555977869293223936
# 21998 2022-08-06 18:03:26+00:00  1555977867174895616  1555977867174895616
# 21999 2022-08-06 18:03:25+00:00  1555977863475724289  1555977863475724288
#
#                                                full_text  truncated  \
# ...

# %%
df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'metadata', 'source', 'user',
#        'is_quote_status', 'retweet_count', 'favorite_count', 'favorited',
#        'retweeted', 'lang'],
#       dtype='object')

# %%
df.select_dtypes(include=np.object)
# Out:
#                                                full_text display_text_range  \
# 0      RT @i_ameztoy: Extra random image (I):\n\nLets...           [0, 143]
# 1      RT @IndoPac_Info: #China's media explains the ...           [0, 140]
# 2      China even cut off communication, they don't a...           [0, 161]
# 3      Putin to #XiJinping : I told you my friend, Ta...           [0, 179]
# 4      RT @ChinaUncensored: I’m sorry, I thought Taiw...           [0, 140]
# ...                                                  ...                ...
# 21995  RT @IndoPac_Info: A good infographic of #China...           [0, 135]
# 21996  RT @IndoPac_Info: A good infographic of #China...           [0, 135]
# 21997                @Reuters Thanks #Pelosi smart move.            [9, 35]
# 21998  RT @IndoPac_Info: #Taiwan people's Desire for ...           [0, 140]
# 21999  RT @IndoPac_Info: #Taiwan people's Desire for ...           [0, 140]
#
# ...

# %%
#visualising data
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
data=pd.DataFrame(np.random.rand(5,16),columns=['created_at', 'id', 'id_str', 'full_text', 'truncated',
       'display_text_range', 'entities', 'metadata', 'source', 'user',
       'is_quote_status', 'retweet_count', 'favorite_count', 'favorited',
       'retweeted', 'lang'])
data.plot.bar();
