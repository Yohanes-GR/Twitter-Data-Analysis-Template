# %%
import pandas as pd

# %%
tweet_list=pd.read_json("data/global_twitter_data.json", lines=True)
tweet_list.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1 2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2 2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3 2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4 2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                            full_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# ...

# %%
tweet_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   created_at                 22000 non-null  datetime64[ns, UTC]
#  1   id                         22000 non-null  int64
#  2   id_str                     22000 non-null  int64
#  3   full_text                  22000 non-null  object
#  4   truncated                  22000 non-null  bool
#  5   display_text_range         22000 non-null  object
#  6   entities                   22000 non-null  object
#  7   metadata                   22000 non-null  object
#  8   source                     22000 non-null  object
#  9   in_reply_to_status_id      897 non-null    float64
#  10  in_reply_to_status_id_str  897 non-null    float64
#  11  in_reply_to_user_id        968 non-null    float64
#  12  in_reply_to_user_id_str    968 non-null    float64
# ...

# %%
tweet_list['retweeted_status'].head(1)
# Out:
# 0    {'created_at': 'Sun Aug 07 20:15:13 +0000 2022...
# Name: retweeted_status, dtype: object
